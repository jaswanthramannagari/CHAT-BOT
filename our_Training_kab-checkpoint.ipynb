# %%
import nltk
from nltk.stem import WordNetLemmatizer
lemmatizer = WordNetLemmatizer()
import json
import pickle

import numpy as np
from keras.models import Sequential
from keras.layers import Dense, Activation, Dropout
from keras.optimizers import SGD
import random

words = []
classes = []
documents = []
ignore_words = ['?', '!','/']
data_file = open('nintents.json').read()
intents = json.loads(data_file)


for intent in intents['intents']:
    for pattern in intent['patterns']:
        #tokenize each word
        w = nltk.word_tokenize(pattern)
        words.extend(w)
        #add documents in the corpus
        documents.append((w, intent['tag']))

        # add to our classes list
        if intent['tag'] not in classes:
            classes.append(intent['tag'])

# lemmaztize and lower each word and remove duplicates
words = [lemmatizer.lemmatize(w.lower()) for w in words if w not in ignore_words]
words = sorted(list(set(words)))
# sort classes
classes = sorted(list(set(classes)))
# documents = combination between patterns and intents
print (len(documents), "documents")
# classes = intents
print (len(classes), "classes", classes)
# words = all words, vocabulary
print (len(words), "unique lemmatized words", words)


pickle.dump(words,open('words.pkl','wb'))
pickle.dump(classes,open('classes.pkl','wb'))

# create our training data
training = []
# create an empty array for our output
output_empty = [0] * len(classes)
# training set, bag of words for each sentence
for doc in documents:
    # initialize our bag of words
    bag = []
    # list of tokenized words for the pattern
    pattern_words = doc[0]
    # lemmatize each word - create base word, in attempt to represent related words
    pattern_words = [lemmatizer.lemmatize(word.lower()) for word in pattern_words]
    # create our bag of words array with 1, if word match found in current pattern
    for w in words:
        bag.append(1) if w in pattern_words else bag.append(0)
    
    # output is a '0' for each tag and '1' for current tag (for each pattern)
    output_row = list(output_empty)
    output_row[classes.index(doc[1])] = 1
    
    training.append([bag, output_row])
# shuffle our features and turn into np.array
random.shuffle(training)
training = np.array(training)
# create train and test lists. X - patterns, Y - intents
train_x = list(training[:,0])
train_y = list(training[:,1])
print("Training data created")


# Create model - 3 layers. First layer 128 neurons, second layer 64 neurons and 3rd output layer contains number of neurons
# equal to number of intents to predict output intent with softmax
model = Sequential()
model.add(Dense(128, input_shape=(len(train_x[0]),), activation='relu'))
model.add(Dropout(0.5))
model.add(Dense(64, activation='relu'))
model.add(Dropout(0.5))
model.add(Dense(len(train_y[0]), activation='softmax'))

# Compile model. Stochastic gradient descent with Nesterov accelerated gradient gives good results for this model
sgd = SGD(lr=0.01, decay=1e-6, momentum=0.9, nesterov=True)
model.compile(loss='categorical_crossentropy', optimizer=sgd, metrics=['accuracy'])

#fitting and saving the model 
hist = model.fit(np.array(train_x), np.array(train_y), epochs=200, batch_size=5, verbose=1)
model.save('chatbot_model_old.h5', hist)

print("model created")
# Out:
# ---------------------------------------------------------------------------
# ImportError                               Traceback (most recent call last)
# <ipython-input-10-f0b98acce88d> in <module>()
#       8 from keras.models import Sequential
#       9 from keras.layers import Dense, Activation, Dropout
# ---> 10 from keras.optimizers import SGD
#      11 import random
#      12
#
# ImportError: cannot import name 'SGD' from 'keras.optimizers' (/usr/local/lib/python3.7/dist-packages/keras/optimizers.py)
#
# ---------------------------------------------------------------------------
# NOTE: If your import is failing due to a missing package, you can
# manually install dependencies using either !pip or !apt.
#
# To view examples of installing some common dependencies, click the
# "Open Examples" button below.
# ---------------------------------------------------------------------------

# %%
from tensorflow.keras.models import Sequential 
from tensorflow.keras.layers import Dense, LSTM, Embedding, Bidirectional
import tensorflow
from tensorflow.keras.layers import Dropout

# %%
# Out:
# 727 documents
# 14 classes ['addiction', 'body_shaming', 'depression', 'family_issue', 'fear', 'goodbye', 'greeting', 'less_competent', 'loneliness', 'physical_ill', 'public_fear', 'sexual_abuse', 'thanks', 'trouble_concentrate']
# 1203 unique lemmatized words ["'", "'d", "'m", "'re", "'s", "'ve", ',', '-', '12', '20', '2002', '2004', '4', ':', 'a', 'able', 'about', 'abuse', 'abused', 'accident', 'according', 'accusation', 'accustomed', 'ache', 'achieve', 'across', 'act', 'action', 'activated', 'activity', 'add', 'addict', 'addicted', 'addiction', 'addictive', 'adequately', 'adjacent', 'adrenaline', 'advantage', 'afraid', 'after', 'afterâ', 'again', 'age', 'agitated', 'alchohol', 'alcoholic', 'all', 'almost', 'alone', 'also', 'always', 'am', 'amateur', 'among', 'amygdala', 'an', 'and', 'anger', 'angry', 'anorexic', 'anti-bark', 'anxiety', 'anxious', 'anymore', 'anyone', 'anything', 'apperance', 'application', 'appreciated', 'apprecipated', 'apprehensive', 'are', 'area', 'areâ', 'arguing', 'argument', 'arm', 'around', 'arrest', 'asked', 'asking', 'assault', 'assaulted', 'asset', 'assulted', 'assumed', 'asthma', 'at', 'atmosphere', 'attempt', 'attempting', 'attend', 'attention', 'attentive', 'attract', 'auditorium', 'autumn', 'average', 'avoidant', 'awesome', 'bad', 'badly', 'badâ', 'bandage', 'bare', 'bark', 'barren', 'be', 'bear', 'became', 'because', 'become', 'becomes', 'been', 'beenâ', 'began', 'behave', 'behaved', 'being', 'believeâ', 'below', 'below-average', 'benefit', 'better', 'between', 'beverage', 'bidding', 'bite', 'bitter', 'black', 'blank', 'bleeding', 'blinking', 'blockage', 'blood', 'blur', 'board', 'body', 'body-shamed', 'body-shameâ', 'bodyâ', 'bored', 'both', 'boundary', 'braver', 'breath', 'breathing', 'broader', 'brother', 'brown', 'buddy', 'bullied', 'but', 'buying', 'by', 'bye', 'ca', 'call', 'called', 'campus', 'can', "can'tâ", 'cancer', 'cant', 'cantilever', 'canvas', 'capable', 'cardiac', 'careful', 'carry', 'cause', 'causing', 'celebration', 'cement', 'change', 'chat', 'chatting', 'child', 'childcare', 'childhood', 'childâ', 'chilly', 'chit', 'circumstance', 'city', 'clarity', 'class', 'classmate', 'classroom', 'clearly', 'close', 'closely', 'clothes', 'cobra', 'cocaine', 'code', 'coffaine', 'coffee', 'cold', 'collar', 'color', 'come', 'coming', 'commenting', 'communicating', 'compeled', 'competent', 'competition', 'competitor', 'completely', 'completing', 'compounded', 'comprehend', 'compulsion', 'compulsive', 'concentrate', 'concentrating', 'concentration', 'conducted', 'conference', 'confidence', 'confusing', 'confusion', 'connection', 'connor', 'consequence', 'consistent', 'consuming', 'consumption', 'contact', 'contaminated', 'content', 'conversation', 'cope', 'correct', 'correctly', 'cost', 'count', 'counterweight', 'cousin', 'cover', 'cramp', 'craved', 'create', 'crime', 'critize', 'critized', 'crowd', 'cruel', 'cure', 'cyber', 'cycle', 'danger', 'dark', 'darkness', 'date', 'day', 'dead', 'deadline', 'debt', 'declining', 'decrease', 'deep', 'dehydrated', 'demonstrated', 'dengue', 'depressed', 'depression', 'deserted', 'despensers', 'desperate', 'destination', 'developed', 'diarrhoea', 'did', 'didnâ€™t', 'differently', 'difficult', 'difficulty', 'diffult', 'disabled', 'disagreement', 'disciple', 'discriminating', 'discussed', 'discussion', 'disease', 'disgusting', 'disheartening', 'disorder', 'dispute', 'disruption', 'distinguished', 'distracted', 'distracting', 'distraction', 'distress', 'distrubance', 'distrubing', 'disturbance', 'do', 'doctor', 'doe', 'dog', 'doing', 'done', 'donâ€™t', 'dopamine', 'down', 'draw', 'dream', 'drinking', 'drug', 'dude', 'due', 'during', 'dusty', 'dying', 'dysentery', 'dysentry', 'each', 'easily', 'easy', 'eat', 'eating', 'eerily', 'effect', 'effectively', 'efficiently', 'embaressing', 'empire', 'employment', 'empty', 'end', 'endured', 'engage', 'enjoying', 'enough', 'entertainment', 'environment', 'eve', 'even', 'ever', 'everybody', 'exaggerated', 'exam', 'excelling', 'excessively', 'excruciating', 'exhausted', 'existing', 'expanding', 'expect', 'experiencing', 'expose', 'exposure', 'express', 'eye', 'face', 'facing', 'factor', 'fail', 'failed', 'fair', 'faith', 'family', 'fantasy', 'fast', ...
# Training data created
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-11-b7bcd17eacde> in <module>
#      81 model = Sequential()
#      82 model.add(Dense(128, input_shape=(len(train_x[0]),), activation='relu'))
# ---> 83 model.add(Bidirectional(LSTM(50,return_sequences=True)))
#      84 model.add(Dropout(0.4))
#      85 model.add(Dense(len(train_y[0]), activation='softmax'))
#
# ~\Anaconda3\envs\guruenv\lib\site-packages\keras\engine\sequential.py in add(self, layer)
#     131             raise TypeError('The added layer must be '
#     132                             'an instance of class Layer. '
# --> 133                             'Found: ' + str(layer))
#     134         self.built = False
#     135         if not self._layers:
#
# TypeError: The added layer must be an instance of class Layer. Found: <tensorflow.python.keras.layers.wrappers.Bidirectional object at 0x000001670DAE5608>

# %%
import nltk
from nltk.stem import WordNetLemmatizer
lemmatizer = WordNetLemmatizer()
import json
import pickle

import numpy as np
from keras.models import Sequential
from keras.layers import Dense, Activation, Dropout
import random

words = []
classes = []
documents = []
ignore_words = ['?', '!','/']
data_file = open('drive/MyDrive/Colab Notebooks/CIP/ours - Copy/nintents.json').read()
intents = json.loads(data_file)


for intent in intents['intents']:
    for pattern in intent['patterns']:
        #tokenize each word
        w = nltk.word_tokenize(pattern)
        words.extend(w)
        #add documents in the corpus
        documents.append((w, intent['tag']))

        # add to our classes list
        if intent['tag'] not in classes:
            classes.append(intent['tag'])

# lemmaztize and lower each word and remove duplicates
words = [lemmatizer.lemmatize(w.lower()) for w in words if w not in ignore_words]
words = sorted(list(set(words)))
# sort classes
classes = sorted(list(set(classes)))
# documents = combination between patterns and intents
print (len(documents), "documents")
# classes = intents
print (len(classes), "classes", classes)
# words = all words, vocabulary
print (len(words), "unique lemmatized words", words)


pickle.dump(words,open('drive/MyDrive/Colab Notebooks/CIP/ours - Copy/words.pkl','wb'))
pickle.dump(classes,open('drive/MyDrive/Colab Notebooks/CIP/ours - Copy/classes.pkl','wb'))

# create our training data
training = []
# create an empty array for our output
output_empty = [0] * len(classes)
# training set, bag of words for each sentence
for doc in documents:
    # initialize our bag of words
    bag = []
    # list of tokenized words for the pattern
    pattern_words = doc[0]
    # lemmatize each word - create base word, in attempt to represent related words
    pattern_words = [lemmatizer.lemmatize(word.lower()) for word in pattern_words]
    # create our bag of words array with 1, if word match found in current pattern
    for w in words:
        bag.append(1) if w in pattern_words else bag.append(0)
    
    # output is a '0' for each tag and '1' for current tag (for each pattern)
    output_row = list(output_empty)
    output_row[classes.index(doc[1])] = 1
    
    training.append([bag, output_row])
# shuffle our features and turn into np.array
random.shuffle(training)
training = np.array(training)
# create train and test lists. X - patterns, Y - intents
train_x = list(training[:,0])
train_y = list(training[:,1])
print("Training data created")

# Create model - 5 layers. First layer 128 neurons, second layer 100 neurons and 3rd output layer contains number of neurons
# equal to number of intents to predict output intent with softmax
from tensorflow.keras.models import Sequential 
from tensorflow.keras.layers import Dense, LSTM, Embedding, Bidirectional
import tensorflow
from tensorflow.keras.layers import Dropout

model = Sequential()
model.add(Bidirectional(LSTM(len(train_x[0]),return_sequences=True)))
model.add(Dropout(0.4))
model.add(Bidirectional(LSTM(100,return_sequences=False)))
model.add(Dense(len(train_y[0]), activation = 'softmax'))

# Compile model. Stochastic gradient descent with Nesterov accelerated gradient gives good results for this model
# sgd = SGD(lr=0.01, decay=1e-6, momentum=0.9, nesterov=True)
# model.compile(loss='categorical_crossentropy', optimizer=sgd, metrics=['accuracy'])
model.compile(loss = 'categorical_crossentropy', optimizer = 'adam',metrics = ['accuracy'])

#fitting and saving the model 
hist = model.fit(np.array(train_x), np.array(train_y), epochs=200, batch_size=5, verbose=1)
model.save('drive/MyDrive/Colab Notebooks/CIP/ours - Copy/chatbot_model3.h5', hist)

print("model created")

import matplotlib.pyplot as plt
plt.plot(hist.history['accuracy'],c='b',label='train accuracy')
plt.legend(loc='lower right')
plt.show()

# from sklearn import metrics
# y_pred = model.predict(y_test)
# print(metrics.classification_report(y_pred, y_test))
# Out:
# 727 documents
# 14 classes ['addiction', 'body_shaming', 'depression', 'family_issue', 'fear', 'goodbye', 'greeting', 'less_competent', 'loneliness', 'physical_ill', 'public_fear', 'sexual_abuse', 'thanks', 'trouble_concentrate']
# 1183 unique lemmatized words ["'", "'d", "'m", "'re", "'s", "'ve", ',', '-', '12', '20', '2002', '2004', '4', ':', 'a', 'able', 'about', 'abuse', 'abused', 'accident', 'according', 'accusation', 'accustomed', 'ache', 'achieve', 'across', 'act', 'action', 'activated', 'activity', 'add', 'addict', 'addicted', 'addiction', 'addictive', 'adequately', 'adjacent', 'adrenaline', 'advantage', 'afraid', 'after', 'again', 'age', 'agitated', 'alchohol', 'alcoholic', 'all', 'almost', 'alone', 'also', 'always', 'am', 'amateur', 'among', 'amygdala', 'an', 'and', 'anger', 'angry', 'anorexic', 'anti-bark', 'anxiety', 'anxious', 'anymore', 'anyone', 'anything', 'apperance', 'application', 'appreciated', 'apprecipated', 'apprehensive', 'are', 'area', 'arguing', 'argument', 'arm', 'around', 'arrest', 'asked', 'asking', 'assault', 'assaulted', 'asset', 'assulted', 'assumed', 'asthma', 'at', 'atmosphere', 'attempt', 'attempting', 'attend', 'attention', 'attentive', 'attract', 'auditorium', 'autumn', 'average', 'avoidant', 'awesome', 'bad', 'badly', 'bandage', 'bare', 'bark', 'barren', 'be', 'bear', 'became', 'because', 'become', 'becomes', 'been', 'began', 'behave', 'behaved', 'being', 'believe', 'below', 'below-average', 'benefit', 'better', 'between', 'beverage', 'bidding', 'bite', 'bitter', 'black', 'blank', 'bleeding', 'blinking', 'blockage', 'blood', 'blur', 'board', 'body', 'body-shame', 'body-shamed', 'bored', 'both', 'boundary', 'braver', 'breath', 'breathing', 'broader', 'brother', 'brown', 'buddy', 'bullied', 'but', 'buying', 'by', 'bye', 'ca', 'call', 'called', 'campus', 'can', "can't", 'cancer', 'cant', 'cantilever', 'canvas', 'capable', 'cardiac', 'careful', 'carry', 'cause', 'causing', 'celebration', 'cement', 'change', 'chat', 'chatting', 'child', 'childcare', 'childhood', 'chilly', 'chit', 'circumstance', 'city', 'clarity', 'class', 'classmate', 'classroom', 'clearly', 'close', 'closely', 'clothes', 'cobra', 'cocaine', 'code', 'coffaine', 'coffee', 'cold', 'collar', 'color', 'come', 'coming', 'commenting', 'communicating', 'compeled', 'competent', 'competition', 'competitor', 'completely', 'completing', 'compounded', 'comprehend', 'compulsion', 'compulsive', 'concentrate', 'concentrating', 'concentration', 'conducted', 'conference', 'confidence', 'confusing', 'confusion', 'connection', 'connor', 'consequence', 'consistent', 'consuming', 'consumption', 'contact', 'contaminated', 'content', 'conversation', 'cope', 'correct', 'correctly', 'cost', 'count', 'counterweight', 'cousin', 'cover', 'cramp', 'craved', 'create', 'crime', 'critize', 'critized', 'crowd', 'cruel', 'cure', 'cyber', 'cycle', 'danger', 'dark', 'darkness', 'date', 'day', 'dead', 'deadline', 'debt', 'declining', 'decrease', 'deep', 'dehydrated', 'demonstrated', 'dengue', 'depressed', 'depression', 'deserted', 'despensers', 'desperate', 'destination', 'developed', 'diarrhoea', 'did', 'didn', 'differently', 'difficult', 'difficulty', 'diffult', 'disabled', 'disagreement', 'disciple', 'discriminating', 'discussed', 'discussion', 'disease', 'disgusting', 'disheartening', 'disorder', 'dispute', 'disruption', 'distinguished', 'distracted', 'distracting', 'distraction', 'distress', 'distrubance', 'distrubing', 'disturbance', 'do', 'doctor', 'doe', 'dog', 'doing', 'don', 'done', 'dopamine', 'down', 'draw', 'dream', 'drinking', 'drug', 'dude', 'due', 'during', 'dusty', 'dying', 'dysentery', 'dysentry', 'each', 'easily', 'easy', 'eat', 'eating', 'eerily', 'effect', 'effectively', 'efficiently', 'embaressing', 'empire', 'employment', 'empty', 'end', 'endured', 'engage', 'enjoying', 'enough', 'entertainment', 'environment', 'eve', 'even', 'ever', 'everybody', 'exaggerated', 'exam', 'excelling', 'excessively', 'excruciating', 'exhausted', 'existing', 'expanding', 'expect', 'experiencing', 'expose', 'exposure', 'express', 'eye', 'face', 'facing', 'factor', 'fail', 'failed', 'fair', 'faith', 'family', 'fantasy', 'fast', 'fat', 'fatal', 'father', 'fatigue', 'fatty', 'fault', 'fear', ' ...
# Training data created
# Epoch 1/200
# /usr/local/lib/python3.7/dist-packages/ipykernel_launcher.py:71: VisibleDeprecationWarning: Creating an ndarray from ragged nested sequences (which is a list-or-tuple of lists-or-tuples-or ndarrays with different lengths or shapes) is deprecated. If you meant to do this, you must specify 'dtype=object' when creating the ndarray.
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# <ipython-input-14-d86de878627d> in <module>()
#      94
#      95 #fitting and saving the model
# ---> 96 hist = model.fit(np.array(train_x), np.array(train_y), epochs=200, batch_size=5, verbose=1)
#      97 model.save('drive/MyDrive/Colab Notebooks/CIP/ours - Copy/chatbot_model3.h5', hist)
#      98
#
# /usr/local/lib/python3.7/dist-packages/keras/utils/traceback_utils.py in error_handler(*args, **kwargs)
#      65     except Exception as e:  # pylint: disable=broad-except
#      66       filtered_tb = _process_traceback_frames(e.__traceback__)
# ---> 67       raise e.with_traceback(filtered_tb) from None
#      68     finally:
#      69       del filtered_tb
#
# /usr/local/lib/python3.7/dist-packages/tensorflow/python/framework/func_graph.py in autograph_handler(*args, **kwargs)
#    1145           except Exception as e:  # pylint:disable=broad-except
#    1146             if hasattr(e, "ag_error_metadata"):
# -> 1147               raise e.ag_error_metadata.to_exception(e)
#    1148             else:
#    1149               raise
#
# ValueError: in user code:
#
#     File "/usr/local/lib/python3.7/dist-packages/keras/engine/training.py", line 1021, in train_function  *
#         return step_function(self, iterator)
#     File "/usr/local/lib/python3.7/dist-packages/keras/engine/training.py", line 1010, in step_function  **
#         outputs = model.distribute_strategy.run(run_step, args=(data,))
#     File "/usr/local/lib/python3.7/dist-packages/keras/engine/training.py", line 1000, in run_step  **
#         outputs = model.train_step(data)
#     File "/usr/local/lib/python3.7/dist-packages/keras/engine/training.py", line 859, in train_step
#         y_pred = self(x, training=True)
#     File "/usr/local/lib/python3.7/dist-packages/keras/utils/traceback_utils.py", line 67, in error_handler
#         raise e.with_traceback(filtered_tb) from None
#     File "/usr/local/lib/python3.7/dist-packages/keras/engine/input_spec.py", line 214, in assert_input_compatibility
#         raise ValueError(f'Input {input_index} of layer "{layer_name}" '
#
#     ValueError: Exception encountered when calling layer "sequential_5" (type Sequential).
#
#     Input 0 of layer "bidirectional_10" is incompatible with the layer: expected ndim=3, found ndim=2. Full shape received: (None, 1183)
#
#     Call arguments received:
#       • inputs=tf.Tensor(shape=(None, 1183), dtype=int64)
#       • training=True
#       • mask=None

# %%
model = Sequential()
model.add(Bidirectional(LSTM(len(train_x[0]),return_sequences=True)))
model.add(Dropout(0.4))
model.add(Bidirectional(LSTM(100,return_sequences=False)))
model.add(Dense(len(train_y[0]), activation = 'softmax'))

# %%
import nltk
nltk.download('punkt')
nltk.download('wordnet')
# Out:
# [nltk_data] Downloading package punkt to /root/nltk_data...
# [nltk_data]   Package punkt is already up-to-date!
# [nltk_data] Downloading package wordnet to /root/nltk_data...
# [nltk_data]   Unzipping corpora/wordnet.zip.
# True

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %%
pip install tensorflow

# %%
from tensorflow.keras.models import Sequential 
from tensorflow.keras.layers import Dense, LSTM, Embedding, Bidirectional
import tensorflow
from tensorflow.keras.layers import Dropout

model = Sequential()
model.add(Embedding(input_dim = 200, output_dim = 100,trainable = False))

model.add(LSTM(100, input_shape=(len(train_x[0]),), activation='relu'))
model.add(Dropout(0.5))
model.add(Dense(64, activation='relu'))
model.add(Dropout(0.5))
model.add(Dense(len(train_y[0]), activation='softmax'))

# %%
import nltk
from nltk.stem import WordNetLemmatizer
lemmatizer = WordNetLemmatizer()
import json
import pickle

import numpy as np
from keras.models import Sequential
from keras.layers import Dense, Activation, Dropout
from keras.optimizers import SGD
import random

words = []
classes = []
documents = []
ignore_words = ['?', '!','/']
data_file = open('nintents.json').read()
intents = json.loads(data_file)


for intent in intents['intents']:
    for pattern in intent['patterns']:
        #tokenize each word
        w = nltk.word_tokenize(pattern)
        words.extend(w)
        #add documents in the corpus
        documents.append((w, intent['tag']))

        # add to our classes list
        if intent['tag'] not in classes:
            classes.append(intent['tag'])

# lemmaztize and lower each word and remove duplicates
words = [lemmatizer.lemmatize(w.lower()) for w in words if w not in ignore_words]
words = sorted(list(set(words)))
# sort classes
classes = sorted(list(set(classes)))
# documents = combination between patterns and intents
print (len(documents), "documents")
# classes = intents
print (len(classes), "classes", classes)
# words = all words, vocabulary
print (len(words), "unique lemmatized words", words)


pickle.dump(words,open('words.pkl','wb'))
pickle.dump(classes,open('classes.pkl','wb'))

# create our training data
training = []
# create an empty array for our output
output_empty = [0] * len(classes)
# training set, bag of words for each sentence
for doc in documents:
    # initialize our bag of words
    bag = []
    # list of tokenized words for the pattern
    pattern_words = doc[0]
    # lemmatize each word - create base word, in attempt to represent related words
    pattern_words = [lemmatizer.lemmatize(word.lower()) for word in pattern_words]
    # create our bag of words array with 1, if word match found in current pattern
    for w in words:
        bag.append(1) if w in pattern_words else bag.append(0)
    
    # output is a '0' for each tag and '1' for current tag (for each pattern)
    output_row = list(output_empty)
    output_row[classes.index(doc[1])] = 1
    
    training.append([bag, output_row])
# shuffle our features and turn into np.array
random.shuffle(training)
training = np.array(training)
# create train and test lists. X - patterns, Y - intents
train_x = list(training[:,0])
train_y = list(training[:,1])
print("Training data created")


# Create model - 3 layers. First layer 128 neurons, second layer 64 neurons and 3rd output layer contains number of neurons
# equal to number of intents to predict output intent with softmax
model = Sequential()
model.add(Dense(128, input_shape=(len(train_x[0]),), activation='relu'))
model.add(Dropout(0.5))
model.add(Dense(64, activation='relu'))
model.add(Dropout(0.5))
model.add(Dense(len(train_y[0]), activation='softmax'))

# Compile model. Stochastic gradient descent with Nesterov accelerated gradient gives good results for this model
sgd = SGD(lr=0.01, decay=1e-6, momentum=0.9, nesterov=True)
model.compile(loss='categorical_crossentropy', optimizer=sgd, metrics=['accuracy'])

#fitting and saving the model 
hist = model.fit(np.array(train_x), np.array(train_y), epochs=200, batch_size=5, verbose=1)
model.save('chatbot_model2.h5', hist)

print("model created")

import matplotlib.pyplot as plt
plt.plot(hist.history['accuracy'],c='b',label='train accuracy')
plt.legend(loc='lower right')
plt.show()
# Out:
# 727 documents
# 14 classes ['addiction', 'body_shaming', 'depression', 'family_issue', 'fear', 'goodbye', 'greeting', 'less_competent', 'loneliness', 'physical_ill', 'public_fear', 'sexual_abuse', 'thanks', 'trouble_concentrate']
# 1203 unique lemmatized words ["'", "'d", "'m", "'re", "'s", "'ve", ',', '-', '12', '20', '2002', '2004', '4', ':', 'a', 'able', 'about', 'abuse', 'abused', 'accident', 'according', 'accusation', 'accustomed', 'ache', 'achieve', 'across', 'act', 'action', 'activated', 'activity', 'add', 'addict', 'addicted', 'addiction', 'addictive', 'adequately', 'adjacent', 'adrenaline', 'advantage', 'afraid', 'after', 'afterâ', 'again', 'age', 'agitated', 'alchohol', 'alcoholic', 'all', 'almost', 'alone', 'also', 'always', 'am', 'amateur', 'among', 'amygdala', 'an', 'and', 'anger', 'angry', 'anorexic', 'anti-bark', 'anxiety', 'anxious', 'anymore', 'anyone', 'anything', 'apperance', 'application', 'appreciated', 'apprecipated', 'apprehensive', 'are', 'area', 'areâ', 'arguing', 'argument', 'arm', 'around', 'arrest', 'asked', 'asking', 'assault', 'assaulted', 'asset', 'assulted', 'assumed', 'asthma', 'at', 'atmosphere', 'attempt', 'attempting', 'attend', 'attention', 'attentive', 'attract', 'auditorium', 'autumn', 'average', 'avoidant', 'awesome', 'bad', 'badly', 'badâ', 'bandage', 'bare', 'bark', 'barren', 'be', 'bear', 'became', 'because', 'become', 'becomes', 'been', 'beenâ', 'began', 'behave', 'behaved', 'being', 'believeâ', 'below', 'below-average', 'benefit', 'better', 'between', 'beverage', 'bidding', 'bite', 'bitter', 'black', 'blank', 'bleeding', 'blinking', 'blockage', 'blood', 'blur', 'board', 'body', 'body-shamed', 'body-shameâ', 'bodyâ', 'bored', 'both', 'boundary', 'braver', 'breath', 'breathing', 'broader', 'brother', 'brown', 'buddy', 'bullied', 'but', 'buying', 'by', 'bye', 'ca', 'call', 'called', 'campus', 'can', "can'tâ", 'cancer', 'cant', 'cantilever', 'canvas', 'capable', 'cardiac', 'careful', 'carry', 'cause', 'causing', 'celebration', 'cement', 'change', 'chat', 'chatting', 'child', 'childcare', 'childhood', 'childâ', 'chilly', 'chit', 'circumstance', 'city', 'clarity', 'class', 'classmate', 'classroom', 'clearly', 'close', 'closely', 'clothes', 'cobra', 'cocaine', 'code', 'coffaine', 'coffee', 'cold', 'collar', 'color', 'come', 'coming', 'commenting', 'communicating', 'compeled', 'competent', 'competition', 'competitor', 'completely', 'completing', 'compounded', 'comprehend', 'compulsion', 'compulsive', 'concentrate', 'concentrating', 'concentration', 'conducted', 'conference', 'confidence', 'confusing', 'confusion', 'connection', 'connor', 'consequence', 'consistent', 'consuming', 'consumption', 'contact', 'contaminated', 'content', 'conversation', 'cope', 'correct', 'correctly', 'cost', 'count', 'counterweight', 'cousin', 'cover', 'cramp', 'craved', 'create', 'crime', 'critize', 'critized', 'crowd', 'cruel', 'cure', 'cyber', 'cycle', 'danger', 'dark', 'darkness', 'date', 'day', 'dead', 'deadline', 'debt', 'declining', 'decrease', 'deep', 'dehydrated', 'demonstrated', 'dengue', 'depressed', 'depression', 'deserted', 'despensers', 'desperate', 'destination', 'developed', 'diarrhoea', 'did', 'didnâ€™t', 'differently', 'difficult', 'difficulty', 'diffult', 'disabled', 'disagreement', 'disciple', 'discriminating', 'discussed', 'discussion', 'disease', 'disgusting', 'disheartening', 'disorder', 'dispute', 'disruption', 'distinguished', 'distracted', 'distracting', 'distraction', 'distress', 'distrubance', 'distrubing', 'disturbance', 'do', 'doctor', 'doe', 'dog', 'doing', 'done', 'donâ€™t', 'dopamine', 'down', 'draw', 'dream', 'drinking', 'drug', 'dude', 'due', 'during', 'dusty', 'dying', 'dysentery', 'dysentry', 'each', 'easily', 'easy', 'eat', 'eating', 'eerily', 'effect', 'effectively', 'efficiently', 'embaressing', 'empire', 'employment', 'empty', 'end', 'endured', 'engage', 'enjoying', 'enough', 'entertainment', 'environment', 'eve', 'even', 'ever', 'everybody', 'exaggerated', 'exam', 'excelling', 'excessively', 'excruciating', 'exhausted', 'existing', 'expanding', 'expect', 'experiencing', 'expose', 'exposure', 'express', 'eye', 'face', 'facing', 'factor', 'fail', 'failed', 'fair', 'faith', 'family', 'fantasy', 'fast', ...
200
# 727/727 [==============================] - 1s 1ms/step - loss: 0.0852 - accuracy: 0.9670
# Epoch 82/200
# 727/727 [==============================] - 1s 1ms/step - loss: 0.0380 - accuracy: 0.9904
# Epoch 83/200
# 727/727 [==============================] - 1s 1ms/step - loss: 0.0853 - accuracy: 0.9752
# Epoch 84/200
# 727/727 [==============================] - 1s 1ms/step - loss: 0.0483 - accuracy: 0.9862
# Epoch 85/200
# 727/727 [==============================] - 1s 1ms/step - loss: 0.0426 - accuracy: 0.9835
# Epoch 86/200
# 727/727 [==============================] - 1s 1ms/step - loss: 0.0322 - accuracy: 0.9904
# Epoch 87/200
# 727/727 [==============================] - 1s 1ms/step - loss: 0.0426 - accuracy: 0.9835
# Epoch 88/200
# 727/727 [==============================] - 1s 1ms/step - loss: 0.0623 - accuracy: 0.9821
# Epoch 89/200
# 727/727 [==============================] - 1s 1ms/step - loss: 0.0335 - accuracy: 0.9904
# Epoch 90/200
# 727/727 [==============================] - 1s 1ms/step - loss: 0.0467 - accuracy: 0.9835
# Epoch 91/200
# 727/727 [==============================] - 1s 1ms/step - loss: 0.0513 - accuracy: 0.9890
# Epoch 92/200
# 727/727 [==============================] - 1s 1ms/step - loss: 0.0343 - accuracy: 0.9890
# Epoch 93/200
# 727/727 [==============================] - 1s 1ms/step - loss: 0.0769 - accuracy: 0.9807
# Epoch 94/200
# 727/727 [==============================] - 1s 1ms/step - loss: 0.0449 - accuracy: 0.9890
# Epoch 95/200
# 727/727 [==============================] - 1s 992us/step - loss: 0.0337 - accuracy: 0.9917
# Epoch 96/200
# 727/727 [==============================] - 1s 1ms/step - loss: 0.0530 - accuracy: 0.9876
# Epoch 97/200
# 727/727 [==============================] - 1s 998us/step - loss: 0.0426 - accuracy: 0.9835
# Epoch 98/200
# 727/727 [==============================] - 1s 1ms/step - loss: 0.0475 - accuracy: 0.9876
# Epoch 99/200
# 727/727 [==============================] - 1s 1ms/step - loss: 0.0372 - accuracy: 0.9876
# Epoch 100/200
# 727/727 [==============================] - 1s 997us/step - loss: 0.0679 - accuracy: 0.9794
# Epoch 101/200
# 727/727 [==============================] - 1s 1ms/step - loss: 0.0421 - accuracy: 0.9876
# Epoch 102/200
# 727/727 [==============================] - 1s 940us/step - loss: 0.0503 - accuracy: 0.9807
# Epoch 103/200
# 727/727 [==============================] - 1s 978us/step - loss: 0.0573 - accuracy: 0.9862
# Epoch 104/200
# 727/727 [==============================] - 1s 1ms/step - loss: 0.0652 - accuracy: 0.9807
# Epoch 105/200
# 727/727 [==============================] - 1s 1ms/step - loss: 0.0491 - accuracy: 0.9807
# Epoch 106/200
# 727/727 [==============================] - 1s 894us/step - loss: 0.0702 - accuracy: 0.9752
# Epoch 107/200
# 727/727 [==============================] - 1s 1ms/step - loss: 0.0584 - accuracy: 0.9835
# Epoch 108/200
# 727/727 [==============================] - 1s 855us/step - loss: 0.0391 - accuracy: 0.9862
# Epoch 109/200
# 727/727 [==============================] - 1s 841us/step - loss: 0.0422 - accuracy: 0.9849
# Epoch 110/200
# 727/727 [==============================] - 1s 805us/step - loss: 0.0514 - accuracy: 0.9821
# Epoch 111/200
# 727/727 [==============================] - 1s 767us/step - loss: 0.0630 - accuracy: 0.9807
# Epoch 112/200
# 727/727 [==============================] - 1s 763us/step - loss: 0.0539 - accuracy: 0.9849
# Epoch 113/200
# 727/727 [==============================] - 1s 1ms/step - loss: 0.0736 - accuracy: 0.9835
# Epoch 114/200
# 727/727 [==============================] - 1s 1ms/step - loss: 0.0553 - accuracy: 0.9876
# Epoch 115/200
# 727/727 [==============================] - 1s 1ms/step - loss: 0.0668 - accuracy: 0.9821
# Epoch 116/200
# 727/727 [==============================] - 1s 1ms/step - loss: 0.0716 - accuracy: 0.9752
# Epoch 117/200
# 727/727 [==============================] - 1s 1ms/step - loss: 0.0783 - accuracy: 0.9752
# Epoch 118/200
# 727/727 [==============================] - 1s 1ms/step - loss: 0.0572 - accuracy: 0.9821
# Epoch 119/200
# 727/727 [==============================] - 1s 1ms/step - loss: 0.0601 - accuracy: 0.9780
# Epoch 120/200
# 727/727 [==============================] - 1s 1ms/step - loss: 0.0320 - accuracy: 0.9890
# Epoch 121/200
# 727/727 [==============================] - 1s 1ms/step - loss: 0.0685 - accuracy: 0.9780
# Epoch 122/200
# 727/727 [==============================] - 1s 1ms/step - loss: 0.0353 - accuracy: 0.9890
# Epoch 123/200
# 727/727 [==============================] - 1s 1ms/step - loss: 0.0512 - accuracy: 0.9862 ETA: 0s - loss: 0
# Epoch 124/200
# 727/727 [==============================] - 1s 1ms/step - loss: 0.0441 - accuracy: 0.9807
# Epoch 125/200
# 727/727 [==============================] - 1s 1ms/step - loss: 0.0503 - accuracy: 0.9835
# Epoch 126/200
# 727/727 [==============================] - 0s 530us/step - loss: 0.0292 - accuracy: 0.9917
# Epoch 127/200
# 727/727 [==============================] - 0s 364us/step - loss: 0.0667 - accuracy: 0.9766
# Epoch 128/200
# 727/727 [==============================] - 1s 819us/step - loss: 0.0836 - accuracy: 0.9752
# Epoch 129/200
# 727/727 [==============================] - 1s 1ms/step - loss: 0.
uracy')
plt.legend(loc='lower right')
plt.show()
# Out:
# 727 documents
# 14 classes ['addiction', 'body_shaming', 'depression', 'family_issue', 'fear', 'goodbye', 'greeting', 'less_competent', 'loneliness', 'physical_ill', 'public_fear', 'sexual_abuse', 'thanks', 'trouble_concentrate']
# 1203 unique lemmatized words ["'", "'d", "'m", "'re", "'s", "'ve", ',', '-', '12', '20', '2002', '2004', '4', ':', 'a', 'able', 'about', 'abuse', 'abused', 'accident', 'according', 'accusation', 'accustomed', 'ache', 'achieve', 'across', 'act', 'action', 'activated', 'activity', 'add', 'addict', 'addicted', 'addiction', 'addictive', 'adequately', 'adjacent', 'adrenaline', 'advantage', 'afraid', 'after', 'afterâ', 'again', 'age', 'agitated', 'alchohol', 'alcoholic', 'all', 'almost', 'alone', 'also', 'always', 'am', 'amateur', 'among', 'amygdala', 'an', 'and', 'anger', 'angry', 'anorexic', 'anti-bark', 'anxiety', 'anxious', 'anymore', 'anyone', 'anything', 'apperance', 'application', 'appreciated', 'apprecipated', 'apprehensive', 'are', 'area', 'areâ', 'arguing', 'argument', 'arm', 'around', 'arrest', 'asked', 'asking', 'assault', 'assaulted', 'asset', 'assulted', 'assumed', 'asthma', 'at', 'atmosphere', 'attempt', 'attempting', 'attend', 'attention', 'attentive', 'attract', 'auditorium', 'autumn', 'average', 'avoidant', 'awesome', 'bad', 'badly', 'badâ', 'bandage', 'bare', 'bark', 'barren', 'be', 'bear', 'became', 'because', 'become', 'becomes', 'been', 'beenâ', 'began', 'behave', 'behaved', 'being', 'believeâ', 'below', 'below-average', 'benefit', 'better', 'between', 'beverage', 'bidding', 'bite', 'bitter', 'black', 'blank', 'bleeding', 'blinking', 'blockage', 'blood', 'blur', 'board', 'body', 'body-shamed', 'body-shameâ', 'bodyâ', 'bored', 'both', 'boundary', 'braver', 'breath', 'breathing', 'broader', 'brother', 'brown', 'buddy', 'bullied', 'but', 'buying', 'by', 'bye', 'ca', 'call', 'called', 'campus', 'can', "can'tâ", 'cancer', 'cant', 'cantilever', 'canvas', 'capable', 'cardiac', 'careful', 'carry', 'cause', 'causing', 'celebration', 'cement', 'change', 'chat', 'chatting', 'child', 'childcare', 'childhood', 'childâ', 'chilly', 'chit', 'circumstance', 'city', 'clarity', 'class', 'classmate', 'classroom', 'clearly', 'close', 'closely', 'clothes', 'cobra', 'cocaine', 'code', 'coffaine', 'coffee', 'cold', 'collar', 'color', 'come', 'coming', 'commenting', 'communicating', 'compeled', 'competent', 'competition', 'competitor', 'completely', 'completing', 'compounded', 'comprehend', 'compulsion', 'compulsive', 'concentrate', 'concentrating', 'concentration', 'conducted', 'conference', 'confidence', 'confusing', 'confusion', 'connection', 'connor', 'consequence', 'consistent', 'consuming', 'consumption', 'contact', 'contaminated', 'content', 'conversation', 'cope', 'correct', 'correctly', 'cost', 'count', 'counterweight', 'cousin', 'cover', 'cramp', 'craved', 'create', 'crime', 'critize', 'critized', 'crowd', 'cruel', 'cure', 'cyber', 'cycle', 'danger', 'dark', 'darkness', 'date', 'day', 'dead', 'deadline', 'debt', 'declining', 'decrease', 'deep', 'dehydrated', 'demonstrated', 'dengue', 'depressed', 'depression', 'deserted', 'despensers', 'desperate', 'destination', 'developed', 'diarrhoea', 'did', 'didnâ€™t', 'differently', 'difficult', 'difficulty', 'diffult', 'disabled', 'disagreement', 'disciple', 'discriminating', 'discussed', 'discussion', 'disease', 'disgusting', 'disheartening', 'disorder', 'dispute', 'disruption', 'distinguished', 'distracted', 'distracting', 'distraction', 'distress', 'distrubance', 'distrubing', 'disturbance', 'do', 'doctor', 'doe', 'dog', 'doing', 'done', 'donâ€™t', 'dopamine', 'down', 'draw', 'dream', 'drinking', 'drug', 'dude', 'due', 'during', 'dusty', 'dying', 'dysentery', 'dysentry', 'each', 'easily', 'easy', 'eat', 'eating', 'eerily', 'effect', 'effectively', 'efficiently', 'embaressing', 'empire', 'employment', 'empty', 'end', 'endured', 'engage', 'enjoying', 'enough', 'entertainment', 'environment', 'eve', 'even', 'ever', 'everybody', 'exaggerated', 'exam', 'excelling', 'excessively', 'excruciating', 'exhausted', 'existing', 'expanding', 'expect', 'experiencing', 'expose', 'exposure', 'express', 'eye', 'face', 'facing', 'factor', 'fail', 'failed', 'fair', 'faith', 'family', 'fantasy', 'fast', ...
# Training data created
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-7-ade16595d5cc> in <module>
#      82 model.add(Dense(128, input_shape=(len(train_x[0]),), activation='relu'))
#      83 model.add(Dropout(0.4))
# ---> 84 model.add(Bidirectional(LSTM(100,return_sequences=True)))
#      85 model.add(Dense(len(train_y[0]), activation='softmax'))
#      86
#
# ~\Anaconda3\envs\guruenv\lib\site-packages\keras\engine\sequential.py in add(self, layer)
#     131             raise TypeError('The added layer must be '
#     132                             'an instance of class Layer. '
# --> 133                             'Found: ' + str(layer))
#     134         self.built = False
#     135         if not self._layers:
#
# TypeError: The added layer must be an instance of class Layer. Found: <tensorflow.python.keras.layers.wrappers.Bidirectional object at 0x000002359C16FC48>

# %%
documents
# Out:
# [(['Hi', 'there'], 'greeting'),
#  (['How', 'are', 'you'], 'greeting'),
#  (['Is', 'anyone', 'there', '?'], 'greeting'),
#  (['Hey'], 'greeting'),
#  (['Hola'], 'greeting'),
#  (['Hello'], 'greeting'),
#  (['Good', 'day'], 'greeting'),
#  (['Bye'], 'goodbye'),
#  (['See', 'you', 'later'], 'goodbye'),
#  (['Goodbye'], 'goodbye'),
#  (['Nice', 'chatting', 'to', 'you', ',', 'bye'], 'goodbye'),
#  (['Till', 'next', 'time'], 'goodbye'),
#  (['Thanks'], 'thanks'),
#  (['Thank', 'you'], 'thanks'),
#  (['That', "'s", 'helpful'], 'thanks'),
#  (['Awesome', ',', 'thanks'], 'thanks'),
#  (['Thanks', 'for', 'helping', 'me'], 'thanks'),
#  (['How', 'you', 'could', 'help', 'me', '?'], 'options'),
#  (['What', 'you', 'can', 'do', '?'], 'options'),
#  (['What', 'help', 'you', 'provide', '?'], 'options'),
#  (['How', 'you', 'can', 'be', 'helpful', '?'], 'options'),
#  (['What', 'support', 'is', 'offered'], 'options'),
#  (['How', 'to', 'check', 'Adverse', 'drug', 'reaction', '?'], 'adverse_drug'),
#  (['Open', 'adverse', 'drugs', 'module'], 'adverse_drug'),
#  (['Give', 'me', 'a', 'list', 'of', 'drugs', 'causing', 'adverse', 'behavior'],
#   'adverse_drug'),
#  (['List',
#    'all',
#    'drugs',
#    'suitable',
#    'for',
#    'patient',
#    'with',
#    'adverse',
#    'reaction'],
#   'adverse_drug'),
#  (['Which', 'drugs', 'dont', 'have', 'adverse', 'reaction', '?'],
#   'adverse_drug'),
#  (['Open', 'blood', 'pressure', 'module'], 'blood_pressure'),
#  (['Task', 'related', 'to', 'blood', 'pressure'], 'blood_pressure'),
#  (['Blood', 'pressure', 'data', 'entry'], 'blood_pressure'),
#  (['I', 'want', 'to', 'log', 'blood', 'pressure', 'results'],
#   'blood_pressure'),
#  (['Blood', 'pressure', 'data', 'management'], 'blood_pressure'),
#  (['I',
#    'want',
#    'to',
#    'search',
#    'for',
#    'blood',
#    'pressure',
#    'result',
#    'history'],
#   'blood_pressure_search'),
#  (['Blood', 'pressure', 'for', 'patient'], 'blood_pressure_search'),
#  (['Load', 'patient', 'blood', 'pressure', 'result'], 'blood_pressure_search'),
#  (['Show', 'blood', 'pressure', 'results', 'for', 'patient'],
#   'blood_pressure_search'),
#  (['Find', 'blood', 'pressure', 'results', 'by', 'ID'],
#   'blood_pressure_search'),
#  (['Find', 'me', 'a', 'pharmacy'], 'pharmacy_search'),
#  (['Find', 'pharmacy'], 'pharmacy_search'),
#  (['List', 'of', 'pharmacies', 'nearby'], 'pharmacy_search'),
#  (['Locate', 'pharmacy'], 'pharmacy_search'),
#  (['Search', 'pharmacy'], 'pharmacy_search'),
#  (['Lookup', 'for', 'hospital'], 'hospital_search'),
#  (['Searching', 'for', 'hospital', 'to', 'transfer', 'patient'],
#   'hospital_search'),
#  (['I', 'want', 'to', 'search', 'hospital', 'data'], 'hospital_search'),
#  (['Hospital', 'lookup', 'for', 'patient'], 'hospital_search'),
#  (['Looking', 'up', 'hospital', 'details'], 'hospital_search')]

# %%
import nltk
from nltk.stem import WordNetLemmatizer
lemmatizer = WordNetLemmatizer()
import json
import pickle

import numpy as np
from keras.models import Sequential
from keras.layers import Dense, Activation, Dropout
import random

words = []
classes = []
documents = []
ignore_words = ['?', '!','/']
data_file = open('drive/MyDrive/Colab Notebooks/CIP/ours - Copy/nintents.json').read()
intents = json.loads(data_file)


for intent in intents['intents']:
    for pattern in intent['patterns']:
        #tokenize each word
        w = nltk.word_tokenize(pattern)
        words.extend(w)
        #add documents in the corpus
        documents.append((w, intent['tag']))

        # add to our classes list
        if intent['tag'] not in classes:
            classes.append(intent['tag'])

# lemmaztize and lower each word and remove duplicates
words = [lemmatizer.lemmatize(w.lower()) for w in words if w not in ignore_words]
words = sorted(list(set(words)))
# sort classes
classes = sorted(list(set(classes)))
# documents = combination between patterns and intents
print (len(documents), "documents")
# classes = intents
print (len(classes), "classes", classes)
# words = all words, vocabulary
print (len(words), "unique lemmatized words", words)


pickle.dump(words,open('drive/MyDrive/Colab Notebooks/CIP/ours - Copy/words.pkl','wb'))
pickle.dump(classes,open('drive/MyDrive/Colab Notebooks/CIP/ours - Copy/classes.pkl','wb'))

# create our training data
training = []
# create an empty array for our output
output_empty = [0] * len(classes)
# training set, bag of words for each sentence
for doc in documents:
    # initialize our bag of words
    bag = []
    # list of tokenized words for the pattern
    pattern_words = doc[0]
    # lemmatize each word - create base word, in attempt to represent related words
    pattern_words = [lemmatizer.lemmatize(word.lower()) for word in pattern_words]
    # create our bag of words array with 1, if word match found in current pattern
    for w in words:
        bag.append(1) if w in pattern_words else bag.append(0)
    
    # output is a '0' for each tag and '1' for current tag (for each pattern)
    output_row = list(output_empty)
    output_row[classes.index(doc[1])] = 1
    
    training.append([bag, output_row])
# shuffle our features and turn into np.array
random.shuffle(training)
training = np.array(training)
# create train and test lists. X - patterns, Y - intents
train_x = list(training[:,0])
train_y = list(training[:,1])
print("Training data created")

# Create model - 5 layers. First layer 128 neurons, second layer 100 neurons and 3rd output layer contains number of neurons
# equal to number of intents to predict output intent with softmax
from tensorflow.keras.models import Sequential 
from tensorflow.keras.layers import Dense, LSTM, Embedding, Bidirectional
import tensorflow
from tensorflow.keras.layers import Dropout

model = Sequential()
model.add(Embedding(input_dim=len(train_x[0]), output_dim = 100, trainable = False))
model.add(Dropout(0.4))
model.add(Bidirectional(LSTM(100,return_sequences=True)))
model.add(Dropout(0.4))
model.add(Bidirectional(LSTM(100,return_sequences=False)))
model.add(Dense(len(train_y[0]), activation = 'softmax'))

# Compile model. Stochastic gradient descent with Nesterov accelerated gradient gives good results for this model
# sgd = SGD(lr=0.01, decay=1e-6, momentum=0.9, nesterov=True)
# model.compile(loss='categorical_crossentropy', optimizer=sgd, metrics=['accuracy'])
model.compile(loss = 'categorical_crossentropy', optimizer = 'adam',metrics = ['accuracy'])

#fitting and saving the model 
hist = model.fit(np.array(train_x), np.array(train_y), epochs=200, batch_size=5, verbose=1)
model.save('drive/MyDrive/Colab Notebooks/CIP/ours - Copy/chatbot_model3.h5', hist)

print("model created")

import matplotlib.pyplot as plt
plt.plot(hist.history['accuracy'],c='b',label='train accuracy')
plt.legend(loc='lower right')
plt.show()
# Out:
# 727 documents
# 14 classes ['addiction', 'body_shaming', 'depression', 'family_issue', 'fear', 'goodbye', 'greeting', 'less_competent', 'loneliness', 'physical_ill', 'public_fear', 'sexual_abuse', 'thanks', 'trouble_concentrate']
# 1183 unique lemmatized words ["'", "'d", "'m", "'re", "'s", "'ve", ',', '-', '12', '20', '2002', '2004', '4', ':', 'a', 'able', 'about', 'abuse', 'abused', 'accident', 'according', 'accusation', 'accustomed', 'ache', 'achieve', 'across', 'act', 'action', 'activated', 'activity', 'add', 'addict', 'addicted', 'addiction', 'addictive', 'adequately', 'adjacent', 'adrenaline', 'advantage', 'afraid', 'after', 'again', 'age', 'agitated', 'alchohol', 'alcoholic', 'all', 'almost', 'alone', 'also', 'always', 'am', 'amateur', 'among', 'amygdala', 'an', 'and', 'anger', 'angry', 'anorexic', 'anti-bark', 'anxiety', 'anxious', 'anymore', 'anyone', 'anything', 'apperance', 'application', 'appreciated', 'apprecipated', 'apprehensive', 'are', 'area', 'arguing', 'argument', 'arm', 'around', 'arrest', 'asked', 'asking', 'assault', 'assaulted', 'asset', 'assulted', 'assumed', 'asthma', 'at', 'atmosphere', 'attempt', 'attempting', 'attend', 'attention', 'attentive', 'attract', 'auditorium', 'autumn', 'average', 'avoidant', 'awesome', 'bad', 'badly', 'bandage', 'bare', 'bark', 'barren', 'be', 'bear', 'became', 'because', 'become', 'becomes', 'been', 'began', 'behave', 'behaved', 'being', 'believe', 'below', 'below-average', 'benefit', 'better', 'between', 'beverage', 'bidding', 'bite', 'bitter', 'black', 'blank', 'bleeding', 'blinking', 'blockage', 'blood', 'blur', 'board', 'body', 'body-shame', 'body-shamed', 'bored', 'both', 'boundary', 'braver', 'breath', 'breathing', 'broader', 'brother', 'brown', 'buddy', 'bullied', 'but', 'buying', 'by', 'bye', 'ca', 'call', 'called', 'campus', 'can', "can't", 'cancer', 'cant', 'cantilever', 'canvas', 'capable', 'cardiac', 'careful', 'carry', 'cause', 'causing', 'celebration', 'cement', 'change', 'chat', 'chatting', 'child', 'childcare', 'childhood', 'chilly', 'chit', 'circumstance', 'city', 'clarity', 'class', 'classmate', 'classroom', 'clearly', 'close', 'closely', 'clothes', 'cobra', 'cocaine', 'code', 'coffaine', 'coffee', 'cold', 'collar', 'color', 'come', 'coming', 'commenting', 'communicating', 'compeled', 'competent', 'competition', 'competitor', 'completely', 'completing', 'compounded', 'comprehend', 'compulsion', 'compulsive', 'concentrate', 'concentrating', 'concentration', 'conducted', 'conference', 'confidence', 'confusing', 'confusion', 'connection', 'connor', 'consequence', 'consistent', 'consuming', 'consumption', 'contact', 'contaminated', 'content', 'conversation', 'cope', 'correct', 'correctly', 'cost', 'count', 'counterweight', 'cousin', 'cover', 'cramp', 'craved', 'create', 'crime', 'critize', 'critized', 'crowd', 'cruel', 'cure', 'cyber', 'cycle', 'danger', 'dark', 'darkness', 'date', 'day', 'dead', 'deadline', 'debt', 'declining', 'decrease', 'deep', 'dehydrated', 'demonstrated', 'dengue', 'depressed', 'depression', 'deserted', 'despensers', 'desperate', 'destination', 'developed', 'diarrhoea', 'did', 'didn', 'differently', 'difficult', 'difficulty', 'diffult', 'disabled', 'disagreement', 'disciple', 'discriminating', 'discussed', 'discussion', 'disease', 'disgusting', 'disheartening', 'disorder', 'dispute', 'disruption', 'distinguished', 'distracted', 'distracting', 'distraction', 'distress', 'distrubance', 'distrubing', 'disturbance', 'do', 'doctor', 'doe', 'dog', 'doing', 'don', 'done', 'dopamine', 'down', 'draw', 'dream', 'drinking', 'drug', 'dude', 'due', 'during', 'dusty', 'dying', 'dysentery', 'dysentry', 'each', 'easily', 'easy', 'eat', 'eating', 'eerily', 'effect', 'effectively', 'efficiently', 'embaressing', 'empire', 'employment', 'empty', 'end', 'endured', 'engage', 'enjoying', 'enough', 'entertainment', 'environment', 'eve', 'even', 'ever', 'everybody', 'exaggerated', 'exam', 'excelling', 'excessively', 'excruciating', 'exhausted', 'existing', 'expanding', 'expect', 'experiencing', 'expose', 'exposure', 'express', 'eye', 'face', 'facing', 'factor', 'fail', 'failed', 'fair', 'faith', 'family', 'fantasy', 'fast', 'fat', 'fatal', 'father', 'fatigue', 'fatty', 'fault', 'fear', ' ...
# /usr/local/lib/python3.7/dist-packages/ipykernel_launcher.py:71: VisibleDeprecationWarning: Creating an ndarray from ragged nested sequences (which is a list-or-tuple of lists-or-tuples-or ndarrays with different lengths or shapes) is deprecated. If you meant to do this, you must specify 'dtype=object' when creating the ndarray.
# Training data created
# Epoch 1/200
# 146/146 [==============================] - 37s 185ms/step - loss: 2.5069 - accuracy: 0.1197
# Epoch 2/200
# 146/146 [==============================] - 26s 181ms/step - loss: 2.4775 - accuracy: 0.1142
# Epoch 3/200
# 146/146 [==============================] - 27s 184ms/step - loss: 2.4657 - accuracy: 0.1197
# Epoch 4/200
# 146/146 [==============================] - 26s 180ms/step - loss: 2.4648 - accuracy: 0.1210
# Epoch 5/200
# 146/146 [==============================] - 26s 181ms/step - loss: 2.4683 - accuracy: 0.1265
# Epoch 6/200
# 146/146 [==============================] - 27s 182ms/step - loss: 2.4628 - accuracy: 0.1348
# Epoch 7/200
# 146/146 [==============================] - 27s 184ms/step - loss: 2.4652 - accuracy: 0.1210
# Epoch 8/200
# 146/146 [==============================] - 26s 181ms/step - loss: 2.4632 - accuracy: 0.1279
# Epoch 9/200
# 146/146 [==============================] - 26s 181ms/step - loss: 2.4569 - accuracy: 0.1320
# Epoch 10/200
# 146/146 [==============================] - 27s 184ms/step - loss: 2.4597 - accuracy: 0.1224
# Epoch 11/200
# 146/146 [==============================] - 27s 183ms/step - loss: 2.4509 - accuracy: 0.1307
# Epoch 12/200
# 146/146 [==============================] - 26s 181ms/step - loss: 2.4519 - accuracy: 0.1279
# Epoch 13/200
# 146/146 [==============================] - 27s 182ms/step - loss: 2.4318 - accuracy: 0.1348
# Epoch 14/200
# 146/146 [==============================] - 26s 181ms/step - loss: 2.4186 - accuracy: 0.1486
# Epoch 15/200
# 146/146 [==============================] - 26s 181ms/step - loss: 2.4144 - accuracy: 0.1210
# Epoch 16/200
# 146/146 [==============================] - 27s 182ms/step - loss: 2.3976 - accuracy: 0.1417
# Epoch 17/200
# 146/146 [==============================] - 26s 181ms/step - loss: 2.3771 - accuracy: 0.1431
# Epoch 18/200
# 146/146 [==============================] - 26s 181ms/step - loss: 2.3612 - accuracy: 0.1596
# Epoch 19/200
# 146/146 [==============================] - 26s 181ms/step - loss: 2.3228 - accuracy: 0.1747
# Epoch 20/200
# 146/146 [==============================] - 26s 181ms/step - loss: 2.2894 - accuracy: 0.1871
# Epoch 21/200
# 146/146 [==============================] - 26s 180ms/step - loss: 2.2621 - accuracy: 0.1981
# Epoch 22/200
# 146/146 [==============================] - 26s 181ms/step - loss: 2.2446 - accuracy: 0.1967
# Epoch 23/200
# 146/146 [==============================] - 26s 180ms/step - loss: 2.2020 - accuracy: 0.2160
# Epoch 24/200
# 146/146 [==============================] - 26s 181ms/step - loss: 2.1983 - accuracy: 0.2132
# Epoch 25/200
# 146/146 [==============================] - 26s 181ms/step - loss: 2.3102 - accuracy: 0.2160
# Epoch 26/200
# 146/146 [==============================] - 26s 179ms/step - loss: 2.5837 - accuracy: 0.1004
# Epoch 27/200
# 146/146 [==============================] - 26s 180ms/step - loss: 2.5162 - accuracy: 0.1265
# Epoch 28/200
# 146/146 [==============================] - 26s 179ms/step - loss: 2.5063 - accuracy: 0.1128
# Epoch 29/200
# 146/146 [==============================] - 26s 179ms/step - loss: 2.5011 - accuracy: 0.1032
# Epoch 30/200
# 146/146 [==============================] - 26s 180ms/step - loss: 2.4712 - accuracy: 0.1293
# Epoch 31/200
# 146/146 [==============================] - 26s 180ms/step - loss: 2.4712 - accuracy: 0.1087
# Epoch 32/200
# 146/146 [==============================] - 26s 180ms/step - loss: 2.4542 - accuracy: 0.1224
# Epoch 33/200
# 146/146 [==============================] - 26s 179ms/step - loss: 2.4684 - accuracy: 0.0990
# Epoch 34/200
# 146/146 [==============================] - 26s 180ms/step - loss: 2.4447 - accuracy: 0.1320
# Epoch 35/200
# 146/146 [==============================] - 26s 181ms/step - loss: 2.4587 - accuracy: 0.1210
# Epoch 36/200
# 146/146 [==============================] - 26s 181ms/step - loss: 2.4419 - accuracy: 0.1279
# Epoch 37/200
# 146/146 [==============================] - 26s 181ms/step - loss: 2.4398 - accuracy: 0.1045
# Epoch 38/200
# 146/146 [==============================] - 26s 180ms/step - loss: 2.4340 - accuracy: 0.1252
# Epoch 39/200
# 146/146 [==============================] - 26s 181ms/step - loss: 2.4311 - accuracy: 0.1348
# Epoch 40/200
# 146/146 [==============================] - 26s 181ms/step - loss: 2.4218 - accuracy: 0.1334
# Epoch 41/200
# 146/146 [==============================] - 26s 181ms/step - loss: 2.4339 - accuracy: 0.1348
# Epoch 42/200
# 146/146 [==============================] - 26s 180ms/step - loss: 2.4257 - accuracy: 0.1431
# Epoch 43/200
# 146/146 [==============================] - 26s 180ms/step - loss: 2.4312 - accuracy: 0.1183
# Epoch 44/200
# 146/146 [==============================] - 26s 180ms/step - loss: 2.4327 - accuracy: 0.1265
# Epoch 45/200
# 146/146 [==============================] - 26s 180ms/step - loss: 2.4303 - accuracy: 0.1320
# Epoch 46/200
# 146/146 [==============================] - 26s 180ms/step - loss: 2.4158 - accuracy: 0.1376
# Epoch 47/200
# 146/146 [==============================] - 26s 181ms/step - loss: 2.4203 - accuracy: 0.1183
# Epoch 48/200
# 146/146 [==============================] - 27s 182ms/step - loss: 2.4201 - accuracy: 0.1403
# Epoch 49/200
# 146/146 [==============================] - 26s 181ms/step - loss: 2.4106 - accuracy: 0.1348
# Epoch 50/200
# 146/146 [==============================] - 26s 181ms/step - loss: 2.4286 - accuracy: 0.1541
# Epoch 51/200
# 146/146 [==============================] - 26s 180ms/step - loss: 2.4253 - accuracy: 0.1376
# Epoch 52/200
# 146/146 [==============================] - 26s 180ms/step - loss: 2.4202 - accuracy: 0.1210
# Epoch 53/200
# 146/146 [==============================] - 26s 180ms/step - loss: 2.3978 - accuracy: 0.1293
# Epoch 54/200
# 146/146 [==============================] - 27s 182ms/step - loss: 2.4137 - accuracy: 0.1197
# Epoch 55/200
# 146/146 [==============================] - 26s 180ms/step - loss: 2.3972 - accuracy: 0.1582
# Epoch 56/200
# 146/146 [==============================] - 26s 181ms/step - loss: 2.4048 - accuracy: 0.1320
# Epoch 57/200
# 146/146 [==============================] - 26s 180ms/step - loss: 2.4062 - accuracy: 0.1334
# Epoch 58/200
# 146/146 [==============================] - 26s 180ms/step - loss: 2.4024 - accuracy: 0.1279
# Epoch 59/200
# 146/146 [==============================] - 26s 180ms/step - loss: 2.3919 - accuracy: 0.1486
# Epoch 60/200
# 146/146 [==============================] - 26s 180ms/step - loss: 2.3923 - accuracy: 0.1609
# Epoch 61/200
# 146/146 [==============================] - 26s 181ms/step - loss: 2.4644 - accuracy: 0.1210
# Epoch 62/200
# 146/146 [==============================] - 26s 181ms/step - loss: 2.4878 - accuracy: 0.1197
# Epoch 63/200
# 146/146 [==============================] - 26s 180ms/step - loss: 2.4526 - accuracy: 0.1114
# Epoch 64/200
# 146/146 [==============================] - 26s 181ms/step - loss: 2.4604 - accuracy: 0.1169
# Epoch 65/200
# 146/146 [==============================] - 26s 180ms/step - loss: 2.4541 - accuracy: 0.0922
# Epoch 66/200
# 146/146 [==============================] - 26s 181ms/step - loss: 2.4527 - accuracy: 0.1362
# Epoch 67/200
# 146/146 [==============================] - 26s 180ms/step - loss: 2.4566 - accuracy: 0.1265
# Epoch 68/200
# 146/146 [==============================] - 26s 180ms/step - loss: 2.4516 - accuracy: 0.1279
# Epoch 69/200
# 146/146 [==============================] - 26s 180ms/step - loss: 2.4396 - accuracy: 0.1293
# Epoch 70/200
# 146/146 [==============================] - 26s 181ms/step - loss: 2.4315 - accuracy: 0.1403
# Epoch 71/200
# 146/146 [==============================] - 26s 181ms/step - loss: 2.4286 - accuracy: 0.1376
# Epoch 72/200
# 146/146 [==============================] - 26s 181ms/step - loss: 2.4192 - accuracy: 0.1279
# Epoch 73/200
# 146/146 [==============================] - 26s 180ms/step - loss: 2.5185 - accuracy: 0.1183
# Epoch 74/200
# 146/146 [==============================] - 26s 179ms/step - loss: 2.5248 - accuracy: 0.1100
# Epoch 75/200
# 146/146 [==============================] - 26s 180ms/step - loss: 2.4688 - accuracy: 0.1224
# Epoch 76/200
# 146/146 [==============================] - 26s 181ms/step - loss: 2.4808 - accuracy: 0.1389
# Epoch 77/200
# 146/146 [==============================] - 26s 181ms/step - loss: 2.4706 - accuracy: 0.1320
# Epoch 78/200
# 146/146 [==============================] - 26s 180ms/step - loss: 2.4720 - accuracy: 0.1293
# Epoch 79/200
# 146/146 [==============================] - 26s 181ms/step - loss: 2.4618 - accuracy: 0.1307
# Epoch 80/200
# 146/146 [==============================] - 26s 181ms/step - loss: 2.4601 - accuracy: 0.1320
# Epoch 81/200
# 146/146 [==============================] - 26s 181ms/step - loss: 2.4480 - accuracy: 0.1238
# Epoch 82/200
# 146/146 [==============================] - 26s 180ms/step - loss: 2.4556 - accuracy: 0.1183
# Epoch 83/200
# 146/146 [==============================] - 26s 180ms/step - loss: 2.4533 - accuracy: 0.1238
# Epoch 84/200
# 146/146 [==============================] - 26s 180ms/step - loss: 2.4521 - accuracy: 0.1293
# Epoch 85/200
# 146/146 [==============================] - 26s 179ms/step - loss: 2.4399 - accuracy: 0.1499
# Epoch 86/200
# 146/146 [==============================] - 26s 179ms/step - loss: 2.4376 - accuracy: 0.1320
# Epoch 87/200
# 146/146 [==============================] - 26s 179ms/step - loss: 2.4364 - accuracy: 0.1389
# Epoch 88/200
# 146/146 [==============================] - 26s 179ms/step - loss: 2.4357 - accuracy: 0.1320
# Epoch 89/200
# 146/146 [==============================] - 26s 179ms/step - loss: 2.4378 - accuracy: 0.1376
# Epoch 90/200
# 146/146 [==============================] - 26s 179ms/step - loss: 2.4278 - accuracy: 0.1444
# Epoch 91/200
# 146/146 [==============================] - 26s 179ms/step - loss: 2.4479 - accuracy: 0.1431
# Epoch 92/200
# 146/146 [==============================] - 26s 180ms/step - loss: 2.4412 - accuracy: 0.1045
# Epoch 93/200
# 146/146 [==============================] - 26s 180ms/step - loss: 2.4284 - accuracy: 0.1444
# Epoch 94/200
# 146/146 [==============================] - 26s 179ms/step - loss: 2.4288 - accuracy: 0.1265
# Epoch 95/200
# 146/146 [==============================] - 26s 180ms/step - loss: 2.4280 - accuracy: 0.1279
# Epoch 96/200
# 146/146 [==============================] - 26s 180ms/step - loss: 2.4255 - accuracy: 0.1417
# Epoch 97/200
# 146/146 [==============================] - 26s 179ms/step - loss: 2.4274 - accuracy: 0.1320
# Epoch 98/200
# 146/146 [==============================] - 26s 178ms/step - loss: 2.4132 - accuracy: 0.1458
# Epoch 99/200
# 146/146 [==============================] - 26s 178ms/step - loss: 2.4191 - accuracy: 0.1389
# Epoch 100/200
# 146/146 [==============================] - 26s 180ms/step - loss: 2.4097 - accuracy: 0.1389
# Epoch 101/200
# 146/146 [==============================] - 26s 180ms/step - loss: 2.4416 - accuracy: 0.1252
# Epoch 102/200
# 146/146 [==============================] - 26s 180ms/step - loss: 2.3929 - accuracy: 0.1389
# Epoch 103/200
# 146/146 [==============================] - 26s 180ms/step - loss: 2.3416 - accuracy: 0.1623
# Epoch 104/200
# 146/146 [==============================] - 26s 181ms/step - loss: 2.3211 - accuracy: 0.1651
# Epoch 105/200
# 146/146 [==============================] - 26s 180ms/step - loss: 2.2783 - accuracy: 0.1884
# Epoch 106/200
# 146/146 [==============================] - 26s 179ms/step - loss: 2.4015 - accuracy: 0.1362
# Epoch 107/200
# 146/146 [==============================] - 26s 180ms/step - loss: 2.4288 - accuracy: 0.1458
# Epoch 108/200
# 146/146 [==============================] - 26s 180ms/step - loss: 2.4201 - accuracy: 0.1486
# Epoch 109/200
# 146/146 [==============================] - 26s 180ms/step - loss: 2.4239 - accuracy: 0.1376
# Epoch 110/200
# 146/146 [==============================] - 26s 179ms/step - loss: 2.4095 - accuracy: 0.1637
# Epoch 111/200
# 146/146 [==============================] - 26s 180ms/step - loss: 2.4026 - accuracy: 0.1568
# Epoch 112/200
# 146/146 [==============================] - 26s 180ms/step - loss: 2.4065 - accuracy: 0.1279
# Epoch 113/200
# 146/146 [==============================] - 26s 180ms/step - loss: 2.3965 - accuracy: 0.1527
# Epoch 114/200
# 146/146 [==============================] - 26s 180ms/step - loss: 2.3909 - accuracy: 0.1623
# Epoch 115/200
# 146/146 [==============================] - 26s 181ms/step - loss: 2.3741 - accuracy: 0.1554
# Epoch 116/200
# 146/146 [==============================] - 26s 181ms/step - loss: 2.3875 - accuracy: 0.1582
# Epoch 117/200
# 146/146 [==============================] - 26s 180ms/step - loss: 2.3866 - accuracy: 0.1582
# Epoch 118/200
# 146/146 [==============================] - 26s 181ms/step - loss: 2.3517 - accuracy: 0.1692
# Epoch 119/200
# 146/146 [==============================] - 26s 181ms/step - loss: 2.3076 - accuracy: 0.1431
# Epoch 120/200
# 146/146 [==============================] - 26s 181ms/step - loss: 2.2819 - accuracy: 0.1816
# Epoch 121/200
# 146/146 [==============================] - 26s 181ms/step - loss: 2.2490 - accuracy: 0.1898
# Epoch 122/200
# 146/146 [==============================] - 26s 181ms/step - loss: 2.2100 - accuracy: 0.2228
# Epoch 123/200
# 146/146 [==============================] - 26s 181ms/step - loss: 2.1787 - accuracy: 0.2352
# Epoch 124/200
# 146/146 [==============================] - 26s 181ms/step - loss: 2.1603 - accuracy: 0.2270
# Epoch 125/200
# 146/146 [==============================] - 26s 181ms/step - loss: 2.1290 - accuracy: 0.2586
# Epoch 126/200
# 146/146 [==============================] - 26s 181ms/step - loss: 2.1249 - accuracy: 0.2655
# Epoch 127/200
# 146/146 [==============================] - 27s 182ms/step - loss: 2.0969 - accuracy: 0.2820
# Epoch 128/200
# 146/146 [==============================] - 27s 182ms/step - loss: 2.0875 - accuracy: 0.2847
# Epoch 129/200
# 146/146 [==============================] - 27s 182ms/step - loss: 2.0739 - accuracy: 0.2916
# Epoch 130/200
# 146/146 [==============================] - 27s 182ms/step - loss: 2.0494 - accuracy: 0.2682
# Epoch 131/200
# 146/146 [==============================] - 27s 182ms/step - loss: 2.0490 - accuracy: 0.2751
# Epoch 132/200
# 146/146 [==============================] - 26s 181ms/step - loss: 2.0229 - accuracy: 0.2875
# Epoch 133/200
# 146/146 [==============================] - 26s 180ms/step - loss: 2.0248 - accuracy: 0.2710
# Epoch 134/200
# 146/146 [==============================] - 26s 180ms/step - loss: 2.0122 - accuracy: 0.2985
# Epoch 135/200
# 146/146 [==============================] - 26s 180ms/step - loss: 1.9905 - accuracy: 0.3012
# Epoch 136/200
# 146/146 [==============================] - 26s 180ms/step - loss: 1.9815 - accuracy: 0.2930
# Epoch 137/200
# 146/146 [==============================] - 26s 180ms/step - loss: 1.9764 - accuracy: 0.3012
# Epoch 138/200
# 146/146 [==============================] - 26s 181ms/step - loss: 2.0096 - accuracy: 0.2985
# Epoch 139/200
# 146/146 [==============================] - 26s 180ms/step - loss: 1.9693 - accuracy: 0.3081
# Epoch 140/200
# 146/146 [==============================] - 26s 180ms/step - loss: 1.9438 - accuracy: 0.3205
# Epoch 141/200
# 146/146 [==============================] - 26s 180ms/step - loss: 1.9442 - accuracy: 0.2916
# Epoch 142/200
# 146/146 [==============================] - 26s 180ms/step - loss: 1.9539 - accuracy: 0.3260
# Epoch 143/200
# 146/146 [==============================] - 26s 180ms/step - loss: 1.9317 - accuracy: 0.3219
# Epoch 144/200
# 146/146 [==============================] - 26s 179ms/step - loss: 1.9416 - accuracy: 0.3232
# Epoch 145/200
# 146/146 [==============================] - 26s 178ms/step - loss: 1.9179 - accuracy: 0.3191
# Epoch 146/200
# 146/146 [==============================] - 26s 180ms/step - loss: 1.9158 - accuracy: 0.3260
# Epoch 147/200
# 146/146 [==============================] - 26s 179ms/step - loss: 1.8956 - accuracy: 0.3205
# Epoch 148/200
# 146/146 [==============================] - 26s 180ms/step - loss: 1.9232 - accuracy: 0.3274
# Epoch 149/200
# 146/146 [==============================] - 26s 180ms/step - loss: 1.9099 - accuracy: 0.3411
# Epoch 150/200
# 146/146 [==============================] - 26s 181ms/step - loss: 1.9273 - accuracy: 0.3164
# Epoch 151/200
# 146/146 [==============================] - 26s 181ms/step - loss: 1.9246 - accuracy: 0.3219
# Epoch 152/200
# 146/146 [==============================] - 26s 181ms/step - loss: 1.9254 - accuracy: 0.3191
# Epoch 153/200
# 146/146 [==============================] - 26s 181ms/step - loss: 1.8759 - accuracy: 0.3370
# Epoch 154/200
# 146/146 [==============================] - 26s 181ms/step - loss: 1.8834 - accuracy: 0.3219
# Epoch 155/200
# 146/146 [==============================] - 27s 182ms/step - loss: 1.8515 - accuracy: 0.3466
# Epoch 156/200
# 146/146 [==============================] - 26s 181ms/step - loss: 1.8486 - accuracy: 0.3439
# Epoch 157/200
# 146/146 [==============================] - 26s 181ms/step - loss: 1.8299 - accuracy: 0.3618
# Epoch 158/200
# 146/146 [==============================] - 26s 180ms/step - loss: 1.8385 - accuracy: 0.3425
# Epoch 159/200
# 146/146 [==============================] - 26s 181ms/step - loss: 1.8408 - accuracy: 0.3535
# Epoch 160/200
# 146/146 [==============================] - 26s 181ms/step - loss: 1.8333 - accuracy: 0.3480
# Epoch 161/200
# 146/146 [==============================] - 27s 182ms/step - loss: 1.8166 - accuracy: 0.3508
# Epoch 162/200
# 146/146 [==============================] - 26s 180ms/step - loss: 1.8013 - accuracy: 0.3521
# Epoch 163/200
# 146/146 [==============================] - 26s 180ms/step - loss: 1.7884 - accuracy: 0.3728
# Epoch 164/200
# 146/146 [==============================] - 27s 183ms/step - loss: 1.8267 - accuracy: 0.3686
# Epoch 165/200
# 146/146 [==============================] - 26s 180ms/step - loss: 1.8093 - accuracy: 0.3673
# Epoch 166/200
# 146/146 [==============================] - 26s 181ms/step - loss: 1.7829 - accuracy: 0.3590
# Epoch 167/200
# 146/146 [==============================] - 26s 181ms/step - loss: 1.7878 - accuracy: 0.3659
# Epoch 168/200
# 146/146 [==============================] - 26s 181ms/step - loss: 1.8115 - accuracy: 0.3439
# Epoch 169/200
# 146/146 [==============================] - 26s 181ms/step - loss: 1.7910 - accuracy: 0.3700
# Epoch 170/200
# 146/146 [==============================] - 26s 181ms/step - loss: 1.8029 - accuracy: 0.3480
# Epoch 171/200
# 146/146 [==============================] - 26s 181ms/step - loss: 1.7679 - accuracy: 0.3838
# Epoch 172/200
# 146/146 [==============================] - 27s 182ms/step - loss: 1.7357 - accuracy: 0.3700
# Epoch 173/200
# 146/146 [==============================] - 26s 181ms/step - loss: 1.7330 - accuracy: 0.3824
# Epoch 174/200
# 146/146 [==============================] - 26s 181ms/step - loss: 1.7293 - accuracy: 0.3893
# Epoch 175/200
# 146/146 [==============================] - 26s 181ms/step - loss: 1.7282 - accuracy: 0.3906
# Epoch 176/200
# 146/146 [==============================] - 26s 181ms/step - loss: 1.7301 - accuracy: 0.3728
# Epoch 177/200
# 146/146 [==============================] - 26s 181ms/step - loss: 1.7544 - accuracy: 0.3783
# Epoch 178/200
# 146/146 [==============================] - 27s 182ms/step - loss: 1.7690 - accuracy: 0.3769
# Epoch 179/200
# 146/146 [==============================] - 26s 181ms/step - loss: 1.7339 - accuracy: 0.3824
# Epoch 180/200
# 146/146 [==============================] - 26s 181ms/step - loss: 1.7471 - accuracy: 0.3893
# Epoch 181/200
# 146/146 [==============================] - 26s 181ms/step - loss: 1.7165 - accuracy: 0.3906
# Epoch 182/200
# 146/146 [==============================] - 26s 181ms/step - loss: 1.7401 - accuracy: 0.3604
# Epoch 183/200
# 146/146 [==============================] - 26s 181ms/step - loss: 1.7477 - accuracy: 0.3645
# Epoch 184/200
# 146/146 [==============================] - 26s 180ms/step - loss: 1.6767 - accuracy: 0.4058
# Epoch 185/200
# 146/146 [==============================] - 26s 181ms/step - loss: 1.6790 - accuracy: 0.4044
# Epoch 186/200
# 146/146 [==============================] - 26s 181ms/step - loss: 1.6788 - accuracy: 0.4237
# Epoch 187/200
# 146/146 [==============================] - 26s 181ms/step - loss: 1.6608 - accuracy: 0.3989
# Epoch 188/200
# 146/146 [==============================] - 26s 181ms/step - loss: 1.6574 - accuracy: 0.4168
# Epoch 189/200
# 146/146 [==============================] - 26s 181ms/step - loss: 1.7121 - accuracy: 0.4044
# Epoch 190/200
# 146/146 [==============================] - 26s 181ms/step - loss: 1.6718 - accuracy: 0.3975
# Epoch 191/200
# 146/146 [==============================] - 26s 181ms/step - loss: 1.6618 - accuracy: 0.3989
# Epoch 192/200
# 146/146 [==============================] - 26s 181ms/step - loss: 1.6254 - accuracy: 0.4292
# Epoch 193/200
# 146/146 [==============================] - 26s 180ms/step - loss: 1.6403 - accuracy: 0.4237
# Epoch 194/200
# 146/146 [==============================] - 26s 180ms/step - loss: 1.6191 - accuracy: 0.4195
# Epoch 195/200
# 146/146 [==============================] - 26s 181ms/step - loss: 1.5896 - accuracy: 0.4525
# Epoch 196/200
# 146/146 [==============================] - 26s 181ms/step - loss: 1.6328 - accuracy: 0.4099
# Epoch 197/200
# 146/146 [==============================] - 26s 181ms/step - loss: 1.5964 - accuracy: 0.4484
# Epoch 198/200
# 146/146 [==============================] - 26s 181ms/step - loss: 1.5875 - accuracy: 0.4374
# Epoch 199/200
# 146/146 [==============================] - 27s 182ms/step - loss: 1.5886 - accuracy: 0.4195
# Epoch 200/200
# 146/146 [==============================] - 26s 181ms/step - loss: 1.5763 - accuracy: 0.4457
# model created

# %%
import nltk
nltk.download('punkt')
nltk.download('wordnet')
# Out:
# [nltk_data] Downloading package punkt to /root/nltk_data...
# [nltk_data]   Unzipping tokenizers/punkt.zip.
# [nltk_data] Downloading package wordnet to /root/nltk_data...
# [nltk_data]   Unzipping corpora/wordnet.zip.
# True

# %%
model = Sequential()
model.add(Dense(128, input_shape=(len(train_x[0]),), activation='relu'))
model.add(Dropout(0.5))
model.add(LSTM(100, activation='relu'))
model.add(Dropout(0.5))
model.add(Dense(len(train_y[0]), activation='softmax'))
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# <ipython-input-20-cf64db301363> in <module>
#       2 model.add(Dense(128, input_shape=(len(train_x[0]),), activation='relu'))
#       3 model.add(Dropout(0.5))
# ----> 4 model.add(LSTM(100, activation='relu'))
#       5 model.add(Dropout(0.5))
#       6 model.add(Dense(len(train_y[0]), activation='softmax'))
#
# ~\Anaconda3\envs\guruenv\lib\site-packages\tensorflow_core\python\training\tracking\base.py in _method_wrapper(self, *args, **kwargs)
#     455     self._self_setattr_tracking = False  # pylint: disable=protected-access
#     456     try:
# --> 457       result = method(self, *args, **kwargs)
#     458     finally:
#     459       self._self_setattr_tracking = previous_value  # pylint: disable=protected-access
#
# ~\Anaconda3\envs\guruenv\lib\site-packages\tensorflow_core\python\keras\engine\sequential.py in add(self, layer)
#     201       # If the model is being built continuously on top of an input layer:
#     202       # refresh its output.
# --> 203       output_tensor = layer(self.outputs[0])
#     204       if len(nest.flatten(output_tensor)) != 1:
#     205         raise TypeError('All layers in a Sequential model '
#
# ~\Anaconda3\envs\guruenv\lib\site-packages\tensorflow_core\python\keras\layers\recurrent.py in __call__(self, inputs, initial_state, constants, **kwargs)
#     642
#     643     if initial_state is None and constants is None:
# --> 644       return super(RNN, self).__call__(inputs, **kwargs)
#     645
#     646     # If any of `initial_state` or `constants` are specified and are Keras
#
# ~\Anaconda3\envs\guruenv\lib\site-packages\tensorflow_core\python\keras\engine\base_layer.py in __call__(self, inputs, *args, **kwargs)
#     735         # are casted, not before.
#     736         input_spec.assert_input_compatibility(self.input_spec, inputs,
# --> 737                                               self.name)
#     738         if (any(isinstance(x, ragged_tensor.RaggedTensor) for x in input_list)
#     739             and self._supports_ragged_inputs is False):  # pylint: disable=g-bool-id-comparison
#
# ~\Anaconda3\envs\guruenv\lib\site-packages\tensorflow_core\python\keras\engine\input_spec.py in assert_input_compatibility(input_spec, inputs, layer_name)
#     175                          'expected ndim=' + str(spec.ndim) + ', found ndim=' +
#     176                          str(ndim) + '. Full shape received: ' +
# --> 177                          str(x.shape.as_list()))
#     178     if spec.max_ndim is not None:
#     179       ndim = x.shape.ndims
#
# ValueError: Input 0 of layer lstm_13 is incompatible with the layer: expected ndim=3, found ndim=2. Full shape received: [None, 128]

# %%
model = Sequential()
model.add(Bidirectional(LSTM(len(train_x[0]),return_sequences=True)))
model.add(Bidirectional(LSTM(100),return_sequences=True))
model.add(Dense(len(train_y[0]), activation='softmax'))
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-19-bf5266600c19> in <module>
#       1 model = Sequential()
#       2 model.add(Bidirectional(LSTM(len(train_x[0]),return_sequences=True)))
# ----> 3 model.add(Bidirectional(LSTM(100),return_sequences=True))
#       4 model.add(Dense(len(train_y[0]), activation='softmax'))
#
# ~\Anaconda3\envs\guruenv\lib\site-packages\tensorflow_core\python\keras\layers\wrappers.py in __init__(self, layer, merge_mode, weights, backward_layer, **kwargs)
#     463     # of it we actually run.
#     464     self._setattr_tracking = False
# --> 465     super(Bidirectional, self).__init__(layer, **kwargs)
#     466     self._setattr_tracking = True
#     467     self.input_spec = layer.input_spec
#
# ~\Anaconda3\envs\guruenv\lib\site-packages\tensorflow_core\python\keras\layers\wrappers.py in __init__(self, layer, **kwargs)
#      56     # to the inputs to the Wrapper layer).
#      57     self._input_map = {}
# ---> 58     super(Wrapper, self).__init__(**kwargs)
#      59
#      60   def build(self, input_shape=None):
#
# ~\Anaconda3\envs\guruenv\lib\site-packages\tensorflow_core\python\training\tracking\base.py in _method_wrapper(self, *args, **kwargs)
#     455     self._self_setattr_tracking = False  # pylint: disable=protected-access
#     456     try:
# --> 457       result = method(self, *args, **kwargs)
#     458     finally:
#     459       self._self_setattr_tracking = previous_value  # pylint: disable=protected-access
#
# ~\Anaconda3\envs\guruenv\lib\site-packages\tensorflow_core\python\keras\engine\base_layer.py in __init__(self, trainable, name, dtype, dynamic, **kwargs)
#     184     }
#     185     # Validate optional keyword arguments.
# --> 186     generic_utils.validate_kwargs(kwargs, allowed_kwargs)
#     187
#     188     # Mutable properties
#
# ~\Anaconda3\envs\guruenv\lib\site-packages\tensorflow_core\python\keras\utils\generic_utils.py in validate_kwargs(kwargs, allowed_kwargs, error_message)
#     716   for kwarg in kwargs:
#     717     if kwarg not in allowed_kwargs:
# --> 718       raise TypeError(error_message, kwarg)
#
# TypeError: ('Keyword argument not understood:', 'return_sequences')

# %%
from tensorflow.keras.models import Sequential 
from tensorflow.keras.layers import Dense, LSTM, Embedding, Bidirectional
import tensorflow
from tensorflow.keras.layers import Dropout

model = Sequential()
model.add(LSTM(20, input_shape=(10, 1), return_sequences=True))

model.compile(loss='binary_crossentropy', optimizer='adam', metrics=['accuracy'])
